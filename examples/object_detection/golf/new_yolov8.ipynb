# %%
# Pip install method (recommended)

# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.179  Python-3.10.5 torch-2.8.0+cpu CPU (Intel Core(TM) Ultra 7 165H)
# Setup complete  (22 CPUs, 15.5 GB RAM, 183.1/308.0 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.179  Python-3.10.5 torch-2.8.0+cpu CPU (Intel Core(TM) Ultra 7 165H)
# Setup complete  (22 CPUs, 15.5 GB RAM, 183.1/308.0 GB disk)

# %% [markdown]
# # File Path

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# c:\Users\Kuljira_AME\pyorbbecsdk_v2\examples\object_detection\golf

# %%
import sys
# !{sys.executable} -m pip install roboflow --user
# Out:
# ...
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    -------- ------------------------------- 7.9/38.8 MB 44.2 MB/s eta 0:00:01
#    --------------- ------------------------ 15.5/38.8 MB 40.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 15.7/38.8 MB 39.7 MB/s eta 0:00:01
#    ------------------------ --------------- 23.9/38.8 MB 29.6 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.8 MB 31.8 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 31.2 MB/s  0:00:01
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 34.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.9 MB 24.6 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.0/9.9 MB 24.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# # Download Datasets after Labelling from Roboflow

# %%
# !mkdir {HOME}new_data
# %cd {HOME}/new_data

# !pip install roboflow --quiet

# from roboflow import Roboflow
# rf = Roboflow(api_key="K9RESibHk1MadCWmsAse")
# project = rf.workspace("kmutt-2luva").project("p-waste")
# dataset = project.version(2).download("yolov8")
# !pip install roboflow --quiet

from roboflow import Roboflow
rf = Roboflow(api_key="K9RESibHk1MadCWmsAse")
project = rf.workspace("kmutt-2luva").project("ggggg-iqgn5")
dataset = project.version(2).download("yolov11")
# Out:
# [WinError 2] The system cannot find the file specified: 'c:\\Users\\Kuljira_AME\\pyorbbecsdk_v2\\examples\\object_detection\\golf/new_data'
# c:\Users\Kuljira_AME\pyorbbecsdk_v2\examples\object_detection\golf
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# try yolov8s or yolov8m for improve accuracy best train19

# %% [markdown]
# # Train

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolo11n.pt data={'C:\\Users\\User\\Desktop\\golf\\ggggg-2\\data.yaml'} epochs=25 imgsz=800 plots=True
# Out:
# c:\Users\User\Desktop\golf
# New https://pypi.org/project/ultralytics/8.3.189 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.13 🚀 Python-3.13.5 torch-2.8.0+cpu CPU (AMD Ryzen 9 9950X 16-Core Processor)
# ...

# %% [markdown]
# # Validate

# %%
# Validate with a new model
# !yolo task=detect mode=val model={HOME}/runs/detect/train4/weights/best.pt data={'C:\\Users\\User\\Desktop\\golf\\ggggg-2\\data.yaml'}
# Out:
# Ultralytics 8.3.13 🚀 Python-3.13.5 torch-2.8.0+cpu CPU (AMD Ryzen 9 9950X 16-Core Processor)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#                    all         40        320      0.957      0.962      0.982      0.851
#                     ng         40        246      0.968      0.988      0.987      0.836
#                   pass         35         74      0.945      0.937      0.978      0.866
# Speed: 0.4ms preprocess, 20.6ms inference, 0.0ms loss, 9.0ms postprocess per image
# Results saved to runs\detect\val4
# 💡 Learn more at https://docs.ultralytics.com/modes/val
# val: Scanning C:\Users\User\Desktop\golf\ggggg-2\valid\labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
# val: Scanning C:\Users\User\Desktop\golf\ggggg-2\valid\labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
# ...

# %% [markdown]
# # Predict

# %%
import matplotlib.pyplot as plt

# Predict with a custom model
# !yolo task=detect mode=predict model={HOME}/runs/detect/train4/weights/best.pt conf=0.25 source={HOME}/color_1756457115.jpg
# Out:
# Ultralytics 8.3.179  Python-3.10.5 torch-2.8.0+cpu CPU (Intel Core(TM) Ultra 7 165H)
# YOLO11n summary (fused): 100 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 c:\Users\Kuljira_AME\pyorbbecsdk_v2\examples\object_detection\golf\color_1756457115.jpg: 480x800 7 ngs, 1 pass, 87.3ms
# Speed: 5.5ms preprocess, 87.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to C:\Users\Kuljira_AME\pyorbbecsdk\runs\detect\predict2
#  Learn more at https://docs.ultralytics.com/modes/predict
